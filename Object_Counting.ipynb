# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.170-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.16.0)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.7.14)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.170-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 15.7 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 99.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 68.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 52.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.1 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 65.5 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 ultralytics-8.3.170 ultralytics-thop-2.0.14

# %%
import cv2

from ultralytics import solutions

cap = cv2.VideoCapture("/content/City Traffic (Stock Footage)(720P_HD).mp4")
assert cap.isOpened(), "Error reading video file"

# region_points = [(20, 400), (1080, 400)]                                      # line counting
region_points = [(20, 400), (1080, 400), (1080, 360), (20, 360)]  # rectangle region
# region_points = [(20, 400), (1080, 400), (1080, 360), (20, 360), (20, 400)]   # polygon region

# Video writer
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))
video_writer = cv2.VideoWriter("object_counting_output.avi", cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

# Initialize object counter object
counter = solutions.ObjectCounter(
    show=True,  # display the output
    region=region_points,  # pass region points
    model="yolo11n.pt",  # model="yolo11n-obb.pt" for object counting with OBB model.
    # classes=[0, 2],  # count specific classes i.e. person and car with COCO pretrained model.
    # tracker="botsort.yaml",  # choose trackers i.e "bytetrack.yaml"
)

# Process video
while cap.isOpened():
    success, im0 = cap.read()

    if not success:
        print("Video frame is empty or processing is complete.")
        break

    results = counter(im0)

    # print(results)  # access the output

    video_writer.write(results.plot_im)  # write the processed frame.

cap.release()
video_writer.release()
cv2.destroyAllWindows()  # destroy all opened windows
# Out:
# Ultralytics Solutions: ✅ {'source': None, 'model': 'yolo11n.pt', 'classes': None, 'show_conf': True, 'show_labels': True, 'region': [(20, 400), (1080, 400), (1080, 360), (20, 360)], 'colormap': 21, 'show_in': True, 'show_out': True, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'figsize': (12.8, 7.2), 'blur_ratio': 0.5, 'vision_point': (20, 20), 'crop_dir': 'cropped-detections', 'json_file': None, 'line_width': 2, 'records': 5, 'fps': 30.0, 'max_hist': 5, 'meter_per_pixel': 0.05, 'max_speed': 120, 'show': True, 'iou': 0.7, 'conf': 0.25, 'device': None, 'max_det': 300, 'half': False, 'tracker': 'botsort.yaml', 'verbose': True, 'data': 'images'}
# 0: 540x960 3.4ms
# Speed: 286.6ms track, 3.4ms solution per image at shape (1, 3, 540, 960)
#
# 1: 540x960 3.6ms
# Speed: 190.9ms track, 3.6ms solution per image at shape (1, 3, 540, 960)
#
# 2: 540x960 4.3ms
# Speed: 185.7ms track, 4.3ms solution per image at shape (1, 3, 540, 960)
#
# 3: 540x960 4.0ms
# Speed: 199.6ms track, 4.0ms solution per image at shape (1, 3, 540, 960)
#
# 4: 540x960 7.2ms
# Speed: 190.6ms track, 7.2ms solution per image at shape (1, 3, 540, 960)
#
# 5: 540x960 3.2ms
# Speed: 214.7ms track, 3.2ms solution per image at shape (1, 3, 540, 960)
#
# 6: 540x960 3.8ms
# Speed: 188.5ms track, 3.8ms solution per image at shape (1, 3, 540, 960)
#
# 7: 540x960 4.1ms
# Speed: 182.3ms track, 4.1ms solution per image at shape (1, 3, 540, 960)
#
# 8: 540x960 3.2ms
# Speed: 185.1ms track, 3.2ms solution per image at shape (1, 3, 540, 960)
#
# 9: 540x960 4.8ms
# Speed: 183.2ms track, 4.8ms solution per image at shape (1, 3, 540, 960)
#
# 10: 540x960 5.6ms
# Speed: 185.7ms track, 5.6ms solution per image at shape (1, 3, 540, 960)
#
# 11: 540x960 3.2ms
# Speed: 191.1ms track, 3.2ms solution per image at shape (1, 3, 540, 960)
#
# 12: 540x960 3.1ms
# Speed: 184.3ms track, 3.1ms solution per image at shape (1, 3, 540, 960)
#
# 13: 540x960 3.5ms
# Speed: 179.6ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 14: 540x960 3.2ms
# Speed: 181.7ms track, 3.2ms solution per image at shape (1, 3, 540, 960)
#
# 15: 540x960 3.6ms
# Speed: 188.5ms track, 3.6ms solution per image at shape (1, 3, 540, 960)
#
# 16: 540x960 2.5ms
# Speed: 200.3ms track, 2.5ms solution per image at shape (1, 3, 540, 960)
#
# 17: 540x960 3.1ms
# Speed: 179.8ms track, 3.1ms solution per image at shape (1, 3, 540, 960)
#
# 18: 540x960 3.8ms
# Speed: 178.1ms track, 3.8ms solution per image at shape (1, 3, 540, 960)
#
# 19: 540x960 3.6ms
# Speed: 189.7ms track, 3.6ms solution per image at shape (1, 3, 540, 960)
#
# 20: 540x960 3.0ms
# Speed: 188.5ms track, 3.0ms solution per image at shape (1, 3, 540, 960)
#
# 21: 540x960 3.8ms
# Speed: 202.3ms track, 3.8ms solution per image at shape (1, 3, 540, 960)
#
# 22: 540x960 3.3ms
# Speed: 194.7ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 23: 540x960 2.5ms
# Speed: 187.4ms track, 2.5ms solution per image at shape (1, 3, 540, 960)
#
# 24: 540x960 3.1ms
# Speed: 189.6ms track, 3.1ms solution per image at shape (1, 3, 540, 960)
#
# 25: 540x960 2.9ms
# Speed: 189.9ms track, 2.9ms solution per image at shape (1, 3, 540, 960)
#
# 26: 540x960 2.4ms
# Speed: 206.7ms track, 2.4ms solution per image at shape (1, 3, 540, 960)
#
# 27: 540x960 4.7ms
# Speed: 189.6ms track, 4.7ms solution per image at shape (1, 3, 540, 960)
#
# 28: 540x960 3.1ms
# Speed: 194.9ms track, 3.1ms solution per image at shape (1, 3, 540, 960)
#
# 29: 540x960 8.0ms
# Speed: 280.0ms track, 8.0ms solution per image at shape (1, 3, 540, 960)
#
# 30: 540x960 4.3ms
# Speed: 316.7ms track, 4.3ms solution per image at shape (1, 3, 540, 960)
#
# 31: 540x960 4.8ms
# Speed: 307.0ms track, 4.8ms solution per image at shape (1, 3, 540, 960)
#
# 32: 540x960 4.7ms
# Speed: 286.7ms track, 4.7ms solution per image at shape (1, 3, 540, 960)
#
# 33: 540x960 3.9ms
# Speed: 294.4ms track, 3.9ms solution per image at shape (1, 3, 540, 960)
#
# 34: 540x960 4.0ms
# Speed: 309.7ms track, 4.0ms solution per image at shape (1, 3, 540, 960)
#
# 35: 540x960 5.3ms
# Speed: 299.2ms track, 5.3ms solution per image at shape (1, 3, 540, 960)
#
# 36: 540x960 5.2ms
# Speed: 297.5ms track, 5.2ms solution per image at shape (1, 3, 540, 960)
#
# 37: 540x960 2.5ms
# Speed: 271.1ms track, 2.5ms solution per image at shape (1, 3, 540, 960)
#
# 38: 540x960 3.7ms
# Speed: 190.1ms track, 3.7ms solution per image at shape (1, 3, 540, 960)
#
# 39: 540x960 2.5ms
# Speed: 203.0ms track, 2.5ms solution per image at shape (1, 3, 540, 960)
#
# 40: 540x960 3.9ms
# Speed: 196.4ms track, 3.9ms solution per image at shape (1, 3, 540, 960)
#
# 41: 540x960 3.8ms
# Speed: 186.9ms track, 3.8ms solution per image at shape (1, 3, 540, 960)
#
# 42: 540x960 2.8ms
# Speed: 201.0ms track, 2.8ms solution per image at shape (1, 3, 540, 960)
#
# 43: 540x960 3.3ms
# Speed: 192.2ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 44: 540x960 2.9ms
# Speed: 191.8ms track, 2.9ms solution per image at shape (1, 3, 540, 960)
#
# 45: 540x960 3.7ms
# Speed: 190.9ms track, 3.7ms solution per image at shape (1, 3, 540, 960)
#
# 46: 540x960 3.4ms
# Speed: 188.0ms track, 3.4ms solution per image at shape (1, 3, 540, 960)
#
# 47: 540x960 3.4ms
# Speed: 207.4ms track, 3.4ms solution per image at shape (1, 3, 540, 960)
#
# 48: 540x960 3.4ms
# Speed: 198.6ms track, 3.4ms solution per image at shape (1, 3, 540, 960)
#
# 49: 540x960 3.6ms
# Speed: 197.6ms track, 3.6ms solution per image at shape (1, 3, 540, 960)
#
# 50: 540x960 3.1ms
# Speed: 204.4ms track, 3.1ms solution per image at shape (1, 3, 540, 960)
#
# 51: 540x960 3.2ms
# Speed: 194.5ms track, 3.2ms solution per image at shape (1, 3, 540, 960)
#
# 52: 540x960 4.1ms
# Speed: 204.3ms track, 4.1ms solution per image at shape (1, 3, 540, 960)
#
# 53: 540x960 5.5ms
# Speed: 204.9ms track, 5.5ms solution per image at shape (1, 3, 540, 960)
#
# 54: 540x960 4.2ms
# Speed: 188.4ms track, 4.2ms solution per image at shape (1, 3, 540, 960)
#
# 55: 540x960 3.3ms
# Speed: 186.9ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 56: 540x960 3.8ms
# Speed: 184.2ms track, 3.8ms solution per image at shape (1, 3, 540, 960)
#
# 57: 540x960 3.3ms
# Speed: 211.8ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 58: 540x960 3.6ms
# Speed: 189.3ms track, 3.6ms solution per image at shape (1, 3, 540, 960)
#
# 59: 540x960 3.7ms
# Speed: 183.8ms track, 3.7ms solution per image at shape (1, 3, 540, 960)
#
# 60: 540x960 4.1ms
# Speed: 191.2ms track, 4.1ms solution per image at shape (1, 3, 540, 960)
#
# 61: 540x960 3.7ms
# Speed: 198.0ms track, 3.7ms solution per image at shape (1, 3, 540, 960)
#
# 62: 540x960 3.4ms
# Speed: 205.6ms track, 3.4ms solution per image at shape (1, 3, 540, 960)
#
# 63: 540x960 3.8ms
# Speed: 190.8ms track, 3.8ms solution per image at shape (1, 3, 540, 960)
#
# 64: 540x960 3.1ms
# Speed: 182.9ms track, 3.1ms solution per image at shape (1, 3, 540, 960)
#
# 65: 540x960 2.9ms
# Speed: 182.8ms track, 2.9ms solution per image at shape (1, 3, 540, 960)
#
# 66: 540x960 4.1ms
# Speed: 188.7ms track, 4.1ms solution per image at shape (1, 3, 540, 960)
#
# 67: 540x960 3.5ms
# Speed: 195.3ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 68: 540x960 4.3ms
# Speed: 182.2ms track, 4.3ms solution per image at shape (1, 3, 540, 960)
#
# 69: 540x960 3.7ms
# Speed: 181.6ms track, 3.7ms solution per image at shape (1, 3, 540, 960)
#
# 70: 540x960 3.3ms
# Speed: 204.2ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 71: 540x960 3.5ms
# Speed: 191.1ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 72: 540x960 3.7ms
# Speed: 208.5ms track, 3.7ms solution per image at shape (1, 3, 540, 960)
#
# 73: 540x960 3.3ms
# Speed: 189.9ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 74: 540x960 3.0ms
# Speed: 193.2ms track, 3.0ms solution per image at shape (1, 3, 540, 960)
#
# 75: 540x960 2.9ms
# Speed: 193.7ms track, 2.9ms solution per image at shape (1, 3, 540, 960)
#
# 76: 540x960 2.6ms
# Speed: 195.5ms track, 2.6ms solution per image at shape (1, 3, 540, 960)
#
# 77: 540x960 3.1ms
# Speed: 201.2ms track, 3.1ms solution per image at shape (1, 3, 540, 960)
#
# 78: 540x960 3.0ms
# Speed: 192.2ms track, 3.0ms solution per image at shape (1, 3, 540, 960)
#
# 79: 540x960 4.1ms
# Speed: 188.6ms track, 4.1ms solution per image at shape (1, 3, 540, 960)
#
# 80: 540x960 3.4ms
# Speed: 185.3ms track, 3.4ms solution per image at shape (1, 3, 540, 960)
#
# 81: 540x960 3.6ms
# Speed: 183.4ms track, 3.6ms solution per image at shape (1, 3, 540, 960)
#
# 82: 540x960 2.9ms
# Speed: 202.6ms track, 2.9ms solution per image at shape (1, 3, 540, 960)
#
# 83: 540x960 3.7ms
# Speed: 188.6ms track, 3.7ms solution per image at shape (1, 3, 540, 960)
#
# 84: 540x960 3.2ms
# Speed: 189.7ms track, 3.2ms solution per image at shape (1, 3, 540, 960)
#
# 85: 540x960 4.3ms
# Speed: 187.3ms track, 4.3ms solution per image at shape (1, 3, 540, 960)
#
# 86: 540x960 4.4ms
# Speed: 275.4ms track, 4.4ms solution per image at shape (1, 3, 540, 960)
#
# 87: 540x960 5.3ms
# Speed: 298.7ms track, 5.3ms solution per image at shape (1, 3, 540, 960)
#
# 88: 540x960 5.8ms
# Speed: 306.8ms track, 5.8ms solution per image at shape (1, 3, 540, 960)
#
# 89: 540x960 4.0ms
# Speed: 293.4ms track, 4.0ms solution per image at shape (1, 3, 540, 960)
#
# 90: 540x960 3.5ms
# Speed: 308.7ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 91: 540x960 4.2ms
# Speed: 302.6ms track, 4.2ms solution per image at shape (1, 3, 540, 960)
#
# 92: 540x960 3.9ms
# Speed: 300.5ms track, 3.9ms solution per image at shape (1, 3, 540, 960)
#
# 93: 540x960 4.6ms
# Speed: 297.7ms track, 4.6ms solution per image at shape (1, 3, 540, 960)
#
# 94: 540x960 2.9ms
# Speed: 246.4ms track, 2.9ms solution per image at shape (1, 3, 540, 960)
#
# 95: 540x960 3.2ms
# Speed: 195.1ms track, 3.2ms solution per image at shape (1, 3, 540, 960)
#
# 96: 540x960 3.3ms
# Speed: 219.3ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 97: 540x960 3.5ms
# Speed: 193.1ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 98: 540x960 3.7ms
# Speed: 207.1ms track, 3.7ms solution per image at shape (1, 3, 540, 960)
#
# 99: 540x960 3.5ms
# Speed: 185.7ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 100: 540x960 3.5ms
# Speed: 184.6ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 101: 540x960 3.5ms
# Speed: 183.6ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 102: 540x960 2.9ms
# Speed: 179.1ms track, 2.9ms solution per image at shape (1, 3, 540, 960)
#
# 103: 540x960 3.3ms
# Speed: 188.7ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 104: 540x960 3.5ms
# Speed: 177.8ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 105: 540x960 3.9ms
# Speed: 183.9ms track, 3.9ms solution per image at shape (1, 3, 540, 960)
#
# 106: 540x960 4.0ms
# Speed: 197.7ms track, 4.0ms solution per image at shape (1, 3, 540, 960)
#
# 107: 540x960 3.4ms
# Speed: 188.6ms track, 3.4ms solution per image at shape (1, 3, 540, 960)
#
# 108: 540x960 3.3ms
# Speed: 203.1ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 109: 540x960 3.3ms
# Speed: 190.1ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 110: 540x960 3.4ms
# Speed: 192.3ms track, 3.4ms solution per image at shape (1, 3, 540, 960)
#
# 111: 540x960 3.9ms
# Speed: 188.2ms track, 3.9ms solution per image at shape (1, 3, 540, 960)
#
# 112: 540x960 3.6ms
# Speed: 185.3ms track, 3.6ms solution per image at shape (1, 3, 540, 960)
#
# 113: 540x960 4.8ms
# Speed: 202.2ms track, 4.8ms solution per image at shape (1, 3, 540, 960)
#
# 114: 540x960 4.6ms
# Speed: 182.1ms track, 4.6ms solution per image at shape (1, 3, 540, 960)
#
# 115: 540x960 3.7ms
# Speed: 187.2ms track, 3.7ms solution per image at shape (1, 3, 540, 960)
#
# 116: 540x960 3.8ms
# Speed: 185.9ms track, 3.8ms solution per image at shape (1, 3, 540, 960)
#
# 117: 540x960 3.4ms
# Speed: 188.7ms track, 3.4ms solution per image at shape (1, 3, 540, 960)
#
# 118: 540x960 5.9ms
# Speed: 194.1ms track, 5.9ms solution per image at shape (1, 3, 540, 960)
#
# 119: 540x960 2.9ms
# Speed: 193.4ms track, 2.9ms solution per image at shape (1, 3, 540, 960)
#
# 120: 540x960 4.0ms
# Speed: 188.1ms track, 4.0ms solution per image at shape (1, 3, 540, 960)
#
# 121: 540x960 2.5ms
# Speed: 191.2ms track, 2.5ms solution per image at shape (1, 3, 540, 960)
#
# 122: 540x960 2.5ms
# Speed: 194.8ms track, 2.5ms solution per image at shape (1, 3, 540, 960)
#
# 123: 540x960 1.8ms
# Speed: 193.3ms track, 1.8ms solution per image at shape (1, 3, 540, 960)
#
# 124: 540x960 2.7ms
# Speed: 200.6ms track, 2.7ms solution per image at shape (1, 3, 540, 960)
#
# 125: 540x960 2.9ms
# Speed: 183.2ms track, 2.9ms solution per image at shape (1, 3, 540, 960)
#
# 126: 540x960 2.5ms
# Speed: 189.4ms track, 2.5ms solution per image at shape (1, 3, 540, 960)
#
# 127: 540x960 1.8ms
# Speed: 194.0ms track, 1.8ms solution per image at shape (1, 3, 540, 960)
#
# 128: 540x960 2.3ms
# Speed: 189.4ms track, 2.3ms solution per image at shape (1, 3, 540, 960)
#
# 129: 540x960 2.2ms
# Speed: 209.1ms track, 2.2ms solution per image at shape (1, 3, 540, 960)
#
# 130: 540x960 3.0ms
# Speed: 186.4ms track, 3.0ms solution per image at shape (1, 3, 540, 960)
#
# 131: 540x960 2.3ms
# Speed: 187.2ms track, 2.3ms solution per image at shape (1, 3, 540, 960)
#
# 132: 540x960 2.6ms
# Speed: 198.4ms track, 2.6ms solution per image at shape (1, 3, 540, 960)
#
# 133: 540x960 4.3ms
# Speed: 191.6ms track, 4.3ms solution per image at shape (1, 3, 540, 960)
#
# 134: 540x960 3.1ms
# Speed: 200.1ms track, 3.1ms solution per image at shape (1, 3, 540, 960)
#
# 135: 540x960 3.8ms
# Speed: 191.0ms track, 3.8ms solution per image at shape (1, 3, 540, 960)
#
# 136: 540x960 3.5ms
# Speed: 190.4ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 137: 540x960 2.8ms
# Speed: 197.1ms track, 2.8ms solution per image at shape (1, 3, 540, 960)
#
# 138: 540x960 2.9ms
# Speed: 187.0ms track, 2.9ms solution per image at shape (1, 3, 540, 960)
#
# 139: 540x960 4.6ms
# Speed: 213.6ms track, 4.6ms solution per image at shape (1, 3, 540, 960)
#
# 140: 540x960 3.1ms
# Speed: 187.3ms track, 3.1ms solution per image at shape (1, 3, 540, 960)
#
# 141: 540x960 3.3ms
# Speed: 187.4ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 142: 540x960 3.2ms
# Speed: 190.6ms track, 3.2ms solution per image at shape (1, 3, 540, 960)
#
# 143: 540x960 5.3ms
# Speed: 267.2ms track, 5.3ms solution per image at shape (1, 3, 540, 960)
#
# 144: 540x960 3.3ms
# Speed: 303.4ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 145: 540x960 3.6ms
# Speed: 325.1ms track, 3.6ms solution per image at shape (1, 3, 540, 960)
#
# 146: 540x960 3.7ms
# Speed: 298.9ms track, 3.7ms solution per image at shape (1, 3, 540, 960)
#
# 147: 540x960 3.7ms
# Speed: 300.3ms track, 3.7ms solution per image at shape (1, 3, 540, 960)
#
# 148: 540x960 3.6ms
# Speed: 276.7ms track, 3.6ms solution per image at shape (1, 3, 540, 960)
#
# 149: 540x960 4.6ms
# Speed: 294.9ms track, 4.6ms solution per image at shape (1, 3, 540, 960)
#
# 150: 540x960 4.1ms
# Speed: 311.1ms track, 4.1ms solution per image at shape (1, 3, 540, 960)
#
# 151: 540x960 2.4ms
# Speed: 263.1ms track, 2.4ms solution per image at shape (1, 3, 540, 960)
#
# 152: 540x960 2.4ms
# Speed: 194.4ms track, 2.4ms solution per image at shape (1, 3, 540, 960)
#
# 153: 540x960 3.0ms
# Speed: 192.5ms track, 3.0ms solution per image at shape (1, 3, 540, 960)
#
# 154: 540x960 2.9ms
# Speed: 190.1ms track, 2.9ms solution per image at shape (1, 3, 540, 960)
#
# 155: 540x960 3.0ms
# Speed: 197.4ms track, 3.0ms solution per image at shape (1, 3, 540, 960)
#
# 156: 540x960 4.6ms
# Speed: 193.0ms track, 4.6ms solution per image at shape (1, 3, 540, 960)
#
# 157: 540x960 2.3ms
# Speed: 192.8ms track, 2.3ms solution per image at shape (1, 3, 540, 960)
#
# 158: 540x960 2.6ms
# Speed: 197.9ms track, 2.6ms solution per image at shape (1, 3, 540, 960)
#
# 159: 540x960 2.4ms
# Speed: 199.6ms track, 2.4ms solution per image at shape (1, 3, 540, 960)
#
# 160: 540x960 1.4ms
# Speed: 209.9ms track, 1.4ms solution per image at shape (1, 3, 540, 960)
#
# 161: 540x960 1.4ms
# Speed: 195.8ms track, 1.4ms solution per image at shape (1, 3, 540, 960)
#
# 162: 540x960 1.9ms
# Speed: 191.4ms track, 1.9ms solution per image at shape (1, 3, 540, 960)
#
# 163: 540x960 2.4ms
# Speed: 200.3ms track, 2.4ms solution per image at shape (1, 3, 540, 960)
#
# 164: 540x960 3.3ms
# Speed: 195.9ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 165: 540x960 2.3ms
# Speed: 200.3ms track, 2.3ms solution per image at shape (1, 3, 540, 960)
#
# 166: 540x960 3.7ms
# Speed: 190.7ms track, 3.7ms solution per image at shape (1, 3, 540, 960)
#
# 167: 540x960 2.1ms
# Speed: 187.6ms track, 2.1ms solution per image at shape (1, 3, 540, 960)
#
# 168: 540x960 2.3ms
# Speed: 187.0ms track, 2.3ms solution per image at shape (1, 3, 540, 960)
#
# 169: 540x960 2.2ms
# Speed: 186.8ms track, 2.2ms solution per image at shape (1, 3, 540, 960)
#
# 170: 540x960 2.4ms
# Speed: 199.4ms track, 2.4ms solution per image at shape (1, 3, 540, 960)
#
# 171: 540x960 3.2ms
# Speed: 189.9ms track, 3.2ms solution per image at shape (1, 3, 540, 960)
#
# 172: 540x960 2.0ms
# Speed: 192.1ms track, 2.0ms solution per image at shape (1, 3, 540, 960)
#
# 173: 540x960 2.1ms
# Speed: 201.1ms track, 2.1ms solution per image at shape (1, 3, 540, 960)
#
# 174: 540x960 3.1ms
# Speed: 187.4ms track, 3.1ms solution per image at shape (1, 3, 540, 960)
#
# 175: 540x960 2.5ms
# Speed: 201.4ms track, 2.5ms solution per image at shape (1, 3, 540, 960)
#
# 176: 540x960 2.7ms
# Speed: 188.9ms track, 2.7ms solution per image at shape (1, 3, 540, 960)
#
# 177: 540x960 2.4ms
# Speed: 181.5ms track, 2.4ms solution per image at shape (1, 3, 540, 960)
#
# 178: 540x960 3.3ms
# Speed: 186.5ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 179: 540x960 2.9ms
# Speed: 188.9ms track, 2.9ms solution per image at shape (1, 3, 540, 960)
#
# 180: 540x960 3.4ms
# Speed: 197.9ms track, 3.4ms solution per image at shape (1, 3, 540, 960)
#
# 181: 540x960 3.3ms
# Speed: 182.8ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 182: 540x960 4.2ms
# Speed: 185.7ms track, 4.2ms solution per image at shape (1, 3, 540, 960)
#
# 183: 540x960 3.4ms
# Speed: 196.3ms track, 3.4ms solution per image at shape (1, 3, 540, 960)
#
# 184: 540x960 3.1ms
# Speed: 179.2ms track, 3.1ms solution per image at shape (1, 3, 540, 960)
#
# 185: 540x960 4.2ms
# Speed: 194.2ms track, 4.2ms solution per image at shape (1, 3, 540, 960)
#
# 186: 540x960 3.1ms
# Speed: 186.3ms track, 3.1ms solution per image at shape (1, 3, 540, 960)
#
# 187: 540x960 2.7ms
# Speed: 196.4ms track, 2.7ms solution per image at shape (1, 3, 540, 960)
#
# 188: 540x960 2.8ms
# Speed: 181.2ms track, 2.8ms solution per image at shape (1, 3, 540, 960)
#
# 189: 540x960 3.2ms
# Speed: 188.4ms track, 3.2ms solution per image at shape (1, 3, 540, 960)
#
# 190: 540x960 4.2ms
# Speed: 201.8ms track, 4.2ms solution per image at shape (1, 3, 540, 960)
#
# 191: 540x960 3.8ms
# Speed: 188.7ms track, 3.8ms solution per image at shape (1, 3, 540, 960)
#
# 192: 540x960 5.0ms
# Speed: 185.5ms track, 5.0ms solution per image at shape (1, 3, 540, 960)
#
# 193: 540x960 3.5ms
# Speed: 185.2ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 194: 540x960 3.6ms
# Speed: 184.9ms track, 3.6ms solution per image at shape (1, 3, 540, 960)
#
# 195: 540x960 4.4ms
# Speed: 192.1ms track, 4.4ms solution per image at shape (1, 3, 540, 960)
#
# 196: 540x960 3.8ms
# Speed: 175.2ms track, 3.8ms solution per image at shape (1, 3, 540, 960)
#
# 197: 540x960 4.0ms
# Speed: 183.3ms track, 4.0ms solution per image at shape (1, 3, 540, 960)
#
# 198: 540x960 3.6ms
# Speed: 185.6ms track, 3.6ms solution per image at shape (1, 3, 540, 960)
#
# 199: 540x960 4.3ms
# Speed: 189.8ms track, 4.3ms solution per image at shape (1, 3, 540, 960)
#
# 200: 540x960 7.2ms
# Speed: 196.9ms track, 7.2ms solution per image at shape (1, 3, 540, 960)
#
# 201: 540x960 7.4ms
# Speed: 307.8ms track, 7.4ms solution per image at shape (1, 3, 540, 960)
#
# 202: 540x960 5.5ms
# Speed: 296.4ms track, 5.5ms solution per image at shape (1, 3, 540, 960)
#
# 203: 540x960 6.2ms
# Speed: 280.9ms track, 6.2ms solution per image at shape (1, 3, 540, 960)
#
# 204: 540x960 5.0ms
# Speed: 303.5ms track, 5.0ms solution per image at shape (1, 3, 540, 960)
#
# 205: 540x960 4.2ms
# Speed: 284.4ms track, 4.2ms solution per image at shape (1, 3, 540, 960)
#
# 206: 540x960 4.5ms
# Speed: 283.8ms track, 4.5ms solution per image at shape (1, 3, 540, 960)
#
# 207: 540x960 6.4ms
# Speed: 289.0ms track, 6.4ms solution per image at shape (1, 3, 540, 960)
#
# 208: 540x960 4.2ms
# Speed: 293.4ms track, 4.2ms solution per image at shape (1, 3, 540, 960)
#
# 209: 540x960 2.8ms
# Speed: 212.7ms track, 2.8ms solution per image at shape (1, 3, 540, 960)
#
# 210: 540x960 2.7ms
# Speed: 189.8ms track, 2.7ms solution per image at shape (1, 3, 540, 960)
#
# 211: 540x960 2.6ms
# Speed: 192.3ms track, 2.6ms solution per image at shape (1, 3, 540, 960)
#
# 212: 540x960 2.7ms
# Speed: 206.4ms track, 2.7ms solution per image at shape (1, 3, 540, 960)
#
# 213: 540x960 3.2ms
# Speed: 193.5ms track, 3.2ms solution per image at shape (1, 3, 540, 960)
#
# 214: 540x960 4.4ms
# Speed: 192.3ms track, 4.4ms solution per image at shape (1, 3, 540, 960)
#
# 215: 540x960 3.0ms
# Speed: 182.4ms track, 3.0ms solution per image at shape (1, 3, 540, 960)
#
# 216: 540x960 2.8ms
# Speed: 189.8ms track, 2.8ms solution per image at shape (1, 3, 540, 960)
#
# 217: 540x960 3.2ms
# Speed: 199.5ms track, 3.2ms solution per image at shape (1, 3, 540, 960)
#
# 218: 540x960 2.9ms
# Speed: 186.2ms track, 2.9ms solution per image at shape (1, 3, 540, 960)
#
# 219: 540x960 4.3ms
# Speed: 183.0ms track, 4.3ms solution per image at shape (1, 3, 540, 960)
#
# 220: 540x960 3.2ms
# Speed: 183.9ms track, 3.2ms solution per image at shape (1, 3, 540, 960)
#
# 221: 540x960 3.9ms
# Speed: 192.2ms track, 3.9ms solution per image at shape (1, 3, 540, 960)
#
# 222: 540x960 5.5ms
# Speed: 220.0ms track, 5.5ms solution per image at shape (1, 3, 540, 960)
#
# 223: 540x960 3.7ms
# Speed: 192.0ms track, 3.7ms solution per image at shape (1, 3, 540, 960)
#
# 224: 540x960 3.7ms
# Speed: 191.7ms track, 3.7ms solution per image at shape (1, 3, 540, 960)
#
# 225: 540x960 3.6ms
# Speed: 189.4ms track, 3.6ms solution per image at shape (1, 3, 540, 960)
#
# 226: 540x960 3.8ms
# Speed: 190.8ms track, 3.8ms solution per image at shape (1, 3, 540, 960)
#
# 227: 540x960 3.5ms
# Speed: 198.2ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 228: 540x960 3.5ms
# Speed: 188.3ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 229: 540x960 3.5ms
# Speed: 188.0ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 230: 540x960 3.7ms
# Speed: 185.5ms track, 3.7ms solution per image at shape (1, 3, 540, 960)
#
# 231: 540x960 3.2ms
# Speed: 187.1ms track, 3.2ms solution per image at shape (1, 3, 540, 960)
#
# 232: 540x960 4.6ms
# Speed: 204.3ms track, 4.6ms solution per image at shape (1, 3, 540, 960)
#
# 233: 540x960 3.4ms
# Speed: 189.3ms track, 3.4ms solution per image at shape (1, 3, 540, 960)
#
# 234: 540x960 3.3ms
# Speed: 206.1ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 235: 540x960 2.6ms
# Speed: 189.4ms track, 2.6ms solution per image at shape (1, 3, 540, 960)
#
# 236: 540x960 3.4ms
# Speed: 189.7ms track, 3.4ms solution per image at shape (1, 3, 540, 960)
#
# 237: 540x960 3.5ms
# Speed: 205.5ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 238: 540x960 2.9ms
# Speed: 181.1ms track, 2.9ms solution per image at shape (1, 3, 540, 960)
#
# 239: 540x960 3.4ms
# Speed: 181.6ms track, 3.4ms solution per image at shape (1, 3, 540, 960)
#
# 240: 540x960 4.1ms
# Speed: 182.5ms track, 4.1ms solution per image at shape (1, 3, 540, 960)
#
# 241: 540x960 3.6ms
# Speed: 179.4ms track, 3.6ms solution per image at shape (1, 3, 540, 960)
#
# 242: 540x960 4.7ms
# Speed: 200.2ms track, 4.7ms solution per image at shape (1, 3, 540, 960)
#
# 243: 540x960 5.3ms
# Speed: 181.8ms track, 5.3ms solution per image at shape (1, 3, 540, 960)
#
# 244: 540x960 4.1ms
# Speed: 180.3ms track, 4.1ms solution per image at shape (1, 3, 540, 960)
#
# 245: 540x960 4.1ms
# Speed: 180.9ms track, 4.1ms solution per image at shape (1, 3, 540, 960)
#
# 246: 540x960 3.9ms
# Speed: 180.2ms track, 3.9ms solution per image at shape (1, 3, 540, 960)
#
# 247: 540x960 7.0ms
# Speed: 194.8ms track, 7.0ms solution per image at shape (1, 3, 540, 960)
#
# 248: 540x960 3.6ms
# Speed: 181.8ms track, 3.6ms solution per image at shape (1, 3, 540, 960)
#
# 249: 540x960 3.5ms
# Speed: 178.4ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 250: 540x960 3.4ms
# Speed: 184.5ms track, 3.4ms solution per image at shape (1, 3, 540, 960)
#
# 251: 540x960 3.5ms
# Speed: 186.4ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 252: 540x960 3.3ms
# Speed: 186.3ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 253: 540x960 3.2ms
# Speed: 197.6ms track, 3.2ms solution per image at shape (1, 3, 540, 960)
#
# 254: 540x960 3.3ms
# Speed: 204.6ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 255: 540x960 3.0ms
# Speed: 194.8ms track, 3.0ms solution per image at shape (1, 3, 540, 960)
#
# 256: 540x960 2.9ms
# Speed: 192.1ms track, 2.9ms solution per image at shape (1, 3, 540, 960)
#
# 257: 540x960 3.5ms
# Speed: 190.3ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 258: 540x960 5.4ms
# Speed: 254.3ms track, 5.4ms solution per image at shape (1, 3, 540, 960)
#
# 259: 540x960 4.4ms
# Speed: 285.0ms track, 4.4ms solution per image at shape (1, 3, 540, 960)
#
# 260: 540x960 7.6ms
# Speed: 308.6ms track, 7.6ms solution per image at shape (1, 3, 540, 960)
#
# 261: 540x960 6.6ms
# Speed: 296.6ms track, 6.6ms solution per image at shape (1, 3, 540, 960)
#
# 262: 540x960 4.3ms
# Speed: 277.5ms track, 4.3ms solution per image at shape (1, 3, 540, 960)
#
# 263: 540x960 4.2ms
# Speed: 273.9ms track, 4.2ms solution per image at shape (1, 3, 540, 960)
#
# 264: 540x960 3.8ms
# Speed: 283.5ms track, 3.8ms solution per image at shape (1, 3, 540, 960)
#
# 265: 540x960 3.9ms
# Speed: 318.4ms track, 3.9ms solution per image at shape (1, 3, 540, 960)
#
# 266: 540x960 5.8ms
# Speed: 295.0ms track, 5.8ms solution per image at shape (1, 3, 540, 960)
#
# 267: 540x960 2.9ms
# Speed: 182.4ms track, 2.9ms solution per image at shape (1, 3, 540, 960)
#
# 268: 540x960 3.6ms
# Speed: 186.6ms track, 3.6ms solution per image at shape (1, 3, 540, 960)
#
# 269: 540x960 3.3ms
# Speed: 199.0ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 270: 540x960 4.1ms
# Speed: 184.7ms track, 4.1ms solution per image at shape (1, 3, 540, 960)
#
# 271: 540x960 3.8ms
# Speed: 191.6ms track, 3.8ms solution per image at shape (1, 3, 540, 960)
#
# 272: 540x960 3.7ms
# Speed: 197.3ms track, 3.7ms solution per image at shape (1, 3, 540, 960)
#
# 273: 540x960 3.4ms
# Speed: 199.7ms track, 3.4ms solution per image at shape (1, 3, 540, 960)
#
# 274: 540x960 4.4ms
# Speed: 203.2ms track, 4.4ms solution per image at shape (1, 3, 540, 960)
#
# 275: 540x960 4.0ms
# Speed: 188.2ms track, 4.0ms solution per image at shape (1, 3, 540, 960)
#
# 276: 540x960 3.9ms
# Speed: 184.0ms track, 3.9ms solution per image at shape (1, 3, 540, 960)
#
# 277: 540x960 6.0ms
# Speed: 189.5ms track, 6.0ms solution per image at shape (1, 3, 540, 960)
#
# 278: 540x960 4.0ms
# Speed: 193.3ms track, 4.0ms solution per image at shape (1, 3, 540, 960)
#
# 279: 540x960 3.9ms
# Speed: 200.2ms track, 3.9ms solution per image at shape (1, 3, 540, 960)
#
# 280: 540x960 5.1ms
# Speed: 187.9ms track, 5.1ms solution per image at shape (1, 3, 540, 960)
#
# 281: 540x960 3.6ms
# Speed: 182.8ms track, 3.6ms solution per image at shape (1, 3, 540, 960)
#
# 282: 540x960 4.7ms
# Speed: 188.2ms track, 4.7ms solution per image at shape (1, 3, 540, 960)
#
# 283: 540x960 4.6ms
# Speed: 193.5ms track, 4.6ms solution per image at shape (1, 3, 540, 960)
#
# 284: 540x960 5.6ms
# Speed: 204.1ms track, 5.6ms solution per image at shape (1, 3, 540, 960)
#
# 285: 540x960 4.9ms
# Speed: 182.1ms track, 4.9ms solution per image at shape (1, 3, 540, 960)
#
# 286: 540x960 5.8ms
# Speed: 168.9ms track, 5.8ms solution per image at shape (1, 3, 540, 960)
#
# 287: 540x960 5.0ms
# Speed: 172.7ms track, 5.0ms solution per image at shape (1, 3, 540, 960)
#
# 288: 540x960 4.8ms
# Speed: 170.3ms track, 4.8ms solution per image at shape (1, 3, 540, 960)
#
# 289: 540x960 5.1ms
# Speed: 188.5ms track, 5.1ms solution per image at shape (1, 3, 540, 960)
#
# 290: 540x960 4.1ms
# Speed: 180.8ms track, 4.1ms solution per image at shape (1, 3, 540, 960)
#
# 291: 540x960 4.1ms
# Speed: 176.6ms track, 4.1ms solution per image at shape (1, 3, 540, 960)
#
# 292: 540x960 4.3ms
# Speed: 175.5ms track, 4.3ms solution per image at shape (1, 3, 540, 960)
#
# 293: 540x960 5.0ms
# Speed: 167.8ms track, 5.0ms solution per image at shape (1, 3, 540, 960)
#
# 294: 540x960 4.1ms
# Speed: 166.3ms track, 4.1ms solution per image at shape (1, 3, 540, 960)
#
# 295: 540x960 3.9ms
# Speed: 186.7ms track, 3.9ms solution per image at shape (1, 3, 540, 960)
#
# 296: 540x960 3.8ms
# Speed: 171.2ms track, 3.8ms solution per image at shape (1, 3, 540, 960)
#
# 297: 540x960 3.4ms
# Speed: 170.8ms track, 3.4ms solution per image at shape (1, 3, 540, 960)
#
# 298: 540x960 3.9ms
# Speed: 170.0ms track, 3.9ms solution per image at shape (1, 3, 540, 960)
#
# 299: 540x960 3.6ms
# Speed: 178.1ms track, 3.6ms solution per image at shape (1, 3, 540, 960)
#
# 300: 540x960 3.5ms
# Speed: 192.7ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 301: 540x960 3.5ms
# Speed: 173.7ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 302: 540x960 3.9ms
# Speed: 169.7ms track, 3.9ms solution per image at shape (1, 3, 540, 960)
#
# 303: 540x960 3.8ms
# Speed: 174.5ms track, 3.8ms solution per image at shape (1, 3, 540, 960)
#
# 304: 540x960 3.3ms
# Speed: 168.9ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 305: 540x960 3.9ms
# Speed: 174.9ms track, 3.9ms solution per image at shape (1, 3, 540, 960)
#
# 306: 540x960 3.7ms
# Speed: 190.1ms track, 3.7ms solution per image at shape (1, 3, 540, 960)
#
# 307: 540x960 2.8ms
# Speed: 176.8ms track, 2.8ms solution per image at shape (1, 3, 540, 960)
#
# 308: 540x960 3.2ms
# Speed: 174.9ms track, 3.2ms solution per image at shape (1, 3, 540, 960)
#
# 309: 540x960 3.0ms
# Speed: 170.4ms track, 3.0ms solution per image at shape (1, 3, 540, 960)
#
# 310: 540x960 3.7ms
# Speed: 174.1ms track, 3.7ms solution per image at shape (1, 3, 540, 960)
#
# 311: 540x960 4.3ms
# Speed: 198.3ms track, 4.3ms solution per image at shape (1, 3, 540, 960)
#
# 312: 540x960 3.4ms
# Speed: 176.8ms track, 3.4ms solution per image at shape (1, 3, 540, 960)
#
# 313: 540x960 3.9ms
# Speed: 173.1ms track, 3.9ms solution per image at shape (1, 3, 540, 960)
#
# 314: 540x960 3.6ms
# Speed: 171.6ms track, 3.6ms solution per image at shape (1, 3, 540, 960)
#
# 315: 540x960 3.5ms
# Speed: 177.2ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 316: 540x960 2.9ms
# Speed: 177.4ms track, 2.9ms solution per image at shape (1, 3, 540, 960)
#
# 317: 540x960 4.2ms
# Speed: 194.9ms track, 4.2ms solution per image at shape (1, 3, 540, 960)
#
# 318: 540x960 4.3ms
# Speed: 279.9ms track, 4.3ms solution per image at shape (1, 3, 540, 960)
#
# 319: 540x960 4.5ms
# Speed: 284.6ms track, 4.5ms solution per image at shape (1, 3, 540, 960)
#
# 320: 540x960 4.9ms
# Speed: 287.5ms track, 4.9ms solution per image at shape (1, 3, 540, 960)
#
# 321: 540x960 5.0ms
# Speed: 278.9ms track, 5.0ms solution per image at shape (1, 3, 540, 960)
#
# 322: 540x960 4.7ms
# Speed: 284.0ms track, 4.7ms solution per image at shape (1, 3, 540, 960)
#
# 323: 540x960 7.1ms
# Speed: 281.1ms track, 7.1ms solution per image at shape (1, 3, 540, 960)
#
# 324: 540x960 5.3ms
# Speed: 274.3ms track, 5.3ms solution per image at shape (1, 3, 540, 960)
#
# 325: 540x960 7.3ms
# Speed: 279.6ms track, 7.3ms solution per image at shape (1, 3, 540, 960)
#
# 326: 540x960 7.3ms
# Speed: 267.5ms track, 7.3ms solution per image at shape (1, 3, 540, 960)
#
# 327: 540x960 4.7ms
# Speed: 180.7ms track, 4.7ms solution per image at shape (1, 3, 540, 960)
#
# 328: 540x960 3.8ms
# Speed: 184.7ms track, 3.8ms solution per image at shape (1, 3, 540, 960)
#
# 329: 540x960 3.5ms
# Speed: 170.8ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 330: 540x960 3.9ms
# Speed: 182.5ms track, 3.9ms solution per image at shape (1, 3, 540, 960)
#
# 331: 540x960 4.3ms
# Speed: 186.3ms track, 4.3ms solution per image at shape (1, 3, 540, 960)
#
# 332: 540x960 3.6ms
# Speed: 174.5ms track, 3.6ms solution per image at shape (1, 3, 540, 960)
#
# 333: 540x960 5.5ms
# Speed: 190.2ms track, 5.5ms solution per image at shape (1, 3, 540, 960)
#
# 334: 540x960 4.3ms
# Speed: 181.2ms track, 4.3ms solution per image at shape (1, 3, 540, 960)
#
# 335: 540x960 5.1ms
# Speed: 177.9ms track, 5.1ms solution per image at shape (1, 3, 540, 960)
#
# 336: 540x960 3.8ms
# Speed: 169.5ms track, 3.8ms solution per image at shape (1, 3, 540, 960)
#
# 337: 540x960 4.3ms
# Speed: 173.1ms track, 4.3ms solution per image at shape (1, 3, 540, 960)
#
# 338: 540x960 4.1ms
# Speed: 174.6ms track, 4.1ms solution per image at shape (1, 3, 540, 960)
#
# 339: 540x960 3.8ms
# Speed: 185.8ms track, 3.8ms solution per image at shape (1, 3, 540, 960)
#
# 340: 540x960 3.8ms
# Speed: 172.4ms track, 3.8ms solution per image at shape (1, 3, 540, 960)
#
# 341: 540x960 4.6ms
# Speed: 175.4ms track, 4.6ms solution per image at shape (1, 3, 540, 960)
#
# 342: 540x960 4.0ms
# Speed: 172.6ms track, 4.0ms solution per image at shape (1, 3, 540, 960)
#
# 343: 540x960 3.7ms
# Speed: 169.0ms track, 3.7ms solution per image at shape (1, 3, 540, 960)
#
# 344: 540x960 3.9ms
# Speed: 191.1ms track, 3.9ms solution per image at shape (1, 3, 540, 960)
#
# 345: 540x960 3.5ms
# Speed: 183.0ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 346: 540x960 3.8ms
# Speed: 176.3ms track, 3.8ms solution per image at shape (1, 3, 540, 960)
#
# 347: 540x960 6.2ms
# Speed: 176.3ms track, 6.2ms solution per image at shape (1, 3, 540, 960)
#
# 348: 540x960 3.7ms
# Speed: 179.7ms track, 3.7ms solution per image at shape (1, 3, 540, 960)
#
# 349: 540x960 3.2ms
# Speed: 175.9ms track, 3.2ms solution per image at shape (1, 3, 540, 960)
#
# 350: 540x960 4.0ms
# Speed: 191.9ms track, 4.0ms solution per image at shape (1, 3, 540, 960)
#
# 351: 540x960 3.5ms
# Speed: 173.0ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 352: 540x960 3.6ms
# Speed: 172.9ms track, 3.6ms solution per image at shape (1, 3, 540, 960)
#
# 353: 540x960 3.1ms
# Speed: 170.0ms track, 3.1ms solution per image at shape (1, 3, 540, 960)
#
# 354: 540x960 2.9ms
# Speed: 168.2ms track, 2.9ms solution per image at shape (1, 3, 540, 960)
#
# 355: 540x960 3.3ms
# Speed: 187.3ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 356: 540x960 3.1ms
# Speed: 178.1ms track, 3.1ms solution per image at shape (1, 3, 540, 960)
#
# 357: 540x960 3.3ms
# Speed: 169.8ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 358: 540x960 3.4ms
# Speed: 175.6ms track, 3.4ms solution per image at shape (1, 3, 540, 960)
#
# 359: 540x960 2.7ms
# Speed: 175.4ms track, 2.7ms solution per image at shape (1, 3, 540, 960)
#
# 360: 540x960 4.1ms
# Speed: 182.7ms track, 4.1ms solution per image at shape (1, 3, 540, 960)
#
# 361: 540x960 3.0ms
# Speed: 186.7ms track, 3.0ms solution per image at shape (1, 3, 540, 960)
#
# 362: 540x960 3.2ms
# Speed: 173.0ms track, 3.2ms solution per image at shape (1, 3, 540, 960)
#
# 363: 540x960 3.6ms
# Speed: 169.6ms track, 3.6ms solution per image at shape (1, 3, 540, 960)
#
# 364: 540x960 3.7ms
# Speed: 185.2ms track, 3.7ms solution per image at shape (1, 3, 540, 960)
#
# 365: 540x960 3.6ms
# Speed: 178.0ms track, 3.6ms solution per image at shape (1, 3, 540, 960)
#
# 366: 540x960 3.4ms
# Speed: 187.0ms track, 3.4ms solution per image at shape (1, 3, 540, 960)
#
# 367: 540x960 3.7ms
# Speed: 183.6ms track, 3.7ms solution per image at shape (1, 3, 540, 960)
#
# 368: 540x960 3.7ms
# Speed: 184.3ms track, 3.7ms solution per image at shape (1, 3, 540, 960)
#
# 369: 540x960 3.8ms
# Speed: 184.0ms track, 3.8ms solution per image at shape (1, 3, 540, 960)
#
# 370: 540x960 5.6ms
# Speed: 177.5ms track, 5.6ms solution per image at shape (1, 3, 540, 960)
#
# 371: 540x960 3.7ms
# Speed: 195.9ms track, 3.7ms solution per image at shape (1, 3, 540, 960)
#
# 372: 540x960 3.7ms
# Speed: 182.5ms track, 3.7ms solution per image at shape (1, 3, 540, 960)
#
# 373: 540x960 3.7ms
# Speed: 175.7ms track, 3.7ms solution per image at shape (1, 3, 540, 960)
#
# 374: 540x960 4.5ms
# Speed: 185.8ms track, 4.5ms solution per image at shape (1, 3, 540, 960)
#
# 375: 540x960 3.9ms
# Speed: 167.3ms track, 3.9ms solution per image at shape (1, 3, 540, 960)
#
# 376: 540x960 3.5ms
# Speed: 176.3ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 377: 540x960 3.1ms
# Speed: 189.8ms track, 3.1ms solution per image at shape (1, 3, 540, 960)
#
# 378: 540x960 2.6ms
# Speed: 195.1ms track, 2.6ms solution per image at shape (1, 3, 540, 960)
#
# 379: 540x960 4.7ms
# Speed: 277.3ms track, 4.7ms solution per image at shape (1, 3, 540, 960)
#
# 380: 540x960 4.1ms
# Speed: 289.4ms track, 4.1ms solution per image at shape (1, 3, 540, 960)
#
# 381: 540x960 6.7ms
# Speed: 277.0ms track, 6.7ms solution per image at shape (1, 3, 540, 960)
#
# 382: 540x960 4.3ms
# Speed: 276.9ms track, 4.3ms solution per image at shape (1, 3, 540, 960)
#
# 383: 540x960 4.5ms
# Speed: 267.9ms track, 4.5ms solution per image at shape (1, 3, 540, 960)
#
# 384: 540x960 4.8ms
# Speed: 314.1ms track, 4.8ms solution per image at shape (1, 3, 540, 960)
#
# 385: 540x960 4.1ms
# Speed: 282.2ms track, 4.1ms solution per image at shape (1, 3, 540, 960)
#
# 386: 540x960 4.2ms
# Speed: 289.0ms track, 4.2ms solution per image at shape (1, 3, 540, 960)
#
# 387: 540x960 2.0ms
# Speed: 266.8ms track, 2.0ms solution per image at shape (1, 3, 540, 960)
#
# 388: 540x960 2.6ms
# Speed: 206.1ms track, 2.6ms solution per image at shape (1, 3, 540, 960)
#
# 389: 540x960 2.6ms
# Speed: 188.6ms track, 2.6ms solution per image at shape (1, 3, 540, 960)
#
# 390: 540x960 2.7ms
# Speed: 182.5ms track, 2.7ms solution per image at shape (1, 3, 540, 960)
#
# 391: 540x960 3.1ms
# Speed: 194.4ms track, 3.1ms solution per image at shape (1, 3, 540, 960)
#
# 392: 540x960 2.2ms
# Speed: 187.8ms track, 2.2ms solution per image at shape (1, 3, 540, 960)
#
# 393: 540x960 2.4ms
# Speed: 197.1ms track, 2.4ms solution per image at shape (1, 3, 540, 960)
#
# 394: 540x960 3.4ms
# Speed: 181.9ms track, 3.4ms solution per image at shape (1, 3, 540, 960)
#
# 395: 540x960 2.3ms
# Speed: 174.4ms track, 2.3ms solution per image at shape (1, 3, 540, 960)
#
# 396: 540x960 2.7ms
# Speed: 181.4ms track, 2.7ms solution per image at shape (1, 3, 540, 960)
#
# 397: 540x960 3.1ms
# Speed: 182.5ms track, 3.1ms solution per image at shape (1, 3, 540, 960)
#
# 398: 540x960 4.0ms
# Speed: 200.0ms track, 4.0ms solution per image at shape (1, 3, 540, 960)
#
# 399: 540x960 3.6ms
# Speed: 189.9ms track, 3.6ms solution per image at shape (1, 3, 540, 960)
#
# 400: 540x960 3.6ms
# Speed: 190.4ms track, 3.6ms solution per image at shape (1, 3, 540, 960)
#
# 401: 540x960 2.7ms
# Speed: 194.3ms track, 2.7ms solution per image at shape (1, 3, 540, 960)
#
# 402: 540x960 2.6ms
# Speed: 188.0ms track, 2.6ms solution per image at shape (1, 3, 540, 960)
#
# 403: 540x960 2.8ms
# Speed: 204.9ms track, 2.8ms solution per image at shape (1, 3, 540, 960)
#
# 404: 540x960 2.5ms
# Speed: 192.8ms track, 2.5ms solution per image at shape (1, 3, 540, 960)
#
# 405: 540x960 2.9ms
# Speed: 188.7ms track, 2.9ms solution per image at shape (1, 3, 540, 960)
#
# 406: 540x960 2.5ms
# Speed: 191.2ms track, 2.5ms solution per image at shape (1, 3, 540, 960)
#
# 407: 540x960 3.0ms
# Speed: 187.1ms track, 3.0ms solution per image at shape (1, 3, 540, 960)
#
# 408: 540x960 5.6ms
# Speed: 194.3ms track, 5.6ms solution per image at shape (1, 3, 540, 960)
#
# 409: 540x960 3.9ms
# Speed: 185.8ms track, 3.9ms solution per image at shape (1, 3, 540, 960)
#
# 410: 540x960 2.7ms
# Speed: 185.8ms track, 2.7ms solution per image at shape (1, 3, 540, 960)
#
# 411: 540x960 3.2ms
# Speed: 188.5ms track, 3.2ms solution per image at shape (1, 3, 540, 960)
#
# 412: 540x960 3.3ms
# Speed: 186.7ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 413: 540x960 3.7ms
# Speed: 181.8ms track, 3.7ms solution per image at shape (1, 3, 540, 960)
#
# 414: 540x960 3.0ms
# Speed: 195.9ms track, 3.0ms solution per image at shape (1, 3, 540, 960)
#
# 415: 540x960 3.0ms
# Speed: 191.1ms track, 3.0ms solution per image at shape (1, 3, 540, 960)
#
# 416: 540x960 4.9ms
# Speed: 240.7ms track, 4.9ms solution per image at shape (1, 3, 540, 960)
#
# 417: 540x960 3.5ms
# Speed: 195.3ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 418: 540x960 4.9ms
# Speed: 189.4ms track, 4.9ms solution per image at shape (1, 3, 540, 960)
#
# 419: 540x960 2.7ms
# Speed: 178.5ms track, 2.7ms solution per image at shape (1, 3, 540, 960)
#
# 420: 540x960 3.2ms
# Speed: 182.5ms track, 3.2ms solution per image at shape (1, 3, 540, 960)
#
# 421: 540x960 2.7ms
# Speed: 178.1ms track, 2.7ms solution per image at shape (1, 3, 540, 960)
#
# 422: 540x960 2.9ms
# Speed: 166.4ms track, 2.9ms solution per image at shape (1, 3, 540, 960)
#
# 423: 540x960 2.7ms
# Speed: 175.1ms track, 2.7ms solution per image at shape (1, 3, 540, 960)
#
# 424: 540x960 3.0ms
# Speed: 181.5ms track, 3.0ms solution per image at shape (1, 3, 540, 960)
#
# 425: 540x960 2.8ms
# Speed: 170.0ms track, 2.8ms solution per image at shape (1, 3, 540, 960)
#
# 426: 540x960 2.5ms
# Speed: 174.4ms track, 2.5ms solution per image at shape (1, 3, 540, 960)
#
# 427: 540x960 3.7ms
# Speed: 176.4ms track, 3.7ms solution per image at shape (1, 3, 540, 960)
#
# 428: 540x960 2.9ms
# Speed: 167.1ms track, 2.9ms solution per image at shape (1, 3, 540, 960)
#
# 429: 540x960 4.4ms
# Speed: 178.0ms track, 4.4ms solution per image at shape (1, 3, 540, 960)
#
# 430: 540x960 2.4ms
# Speed: 170.9ms track, 2.4ms solution per image at shape (1, 3, 540, 960)
#
# 431: 540x960 3.0ms
# Speed: 167.6ms track, 3.0ms solution per image at shape (1, 3, 540, 960)
#
# 432: 540x960 2.8ms
# Speed: 165.8ms track, 2.8ms solution per image at shape (1, 3, 540, 960)
#
# 433: 540x960 2.9ms
# Speed: 169.7ms track, 2.9ms solution per image at shape (1, 3, 540, 960)
#
# 434: 540x960 3.1ms
# Speed: 164.0ms track, 3.1ms solution per image at shape (1, 3, 540, 960)
#
# 435: 540x960 3.7ms
# Speed: 181.0ms track, 3.7ms solution per image at shape (1, 3, 540, 960)
#
# 436: 540x960 3.0ms
# Speed: 163.0ms track, 3.0ms solution per image at shape (1, 3, 540, 960)
#
# 437: 540x960 3.1ms
# Speed: 160.4ms track, 3.1ms solution per image at shape (1, 3, 540, 960)
#
# 438: 540x960 5.3ms
# Speed: 209.9ms track, 5.3ms solution per image at shape (1, 3, 540, 960)
#
# 439: 540x960 5.8ms
# Speed: 260.7ms track, 5.8ms solution per image at shape (1, 3, 540, 960)
#
# 440: 540x960 4.3ms
# Speed: 259.4ms track, 4.3ms solution per image at shape (1, 3, 540, 960)
#
# 441: 540x960 3.9ms
# Speed: 248.8ms track, 3.9ms solution per image at shape (1, 3, 540, 960)
#
# 442: 540x960 4.6ms
# Speed: 251.3ms track, 4.6ms solution per image at shape (1, 3, 540, 960)
#
# 443: 540x960 5.1ms
# Speed: 253.8ms track, 5.1ms solution per image at shape (1, 3, 540, 960)
#
# 444: 540x960 9.0ms
# Speed: 275.1ms track, 9.0ms solution per image at shape (1, 3, 540, 960)
#
# 445: 540x960 6.3ms
# Speed: 286.7ms track, 6.3ms solution per image at shape (1, 3, 540, 960)
#
# 446: 540x960 8.1ms
# Speed: 269.5ms track, 8.1ms solution per image at shape (1, 3, 540, 960)
#
# 447: 540x960 7.7ms
# Speed: 266.0ms track, 7.7ms solution per image at shape (1, 3, 540, 960)
#
# 448: 540x960 3.7ms
# Speed: 182.3ms track, 3.7ms solution per image at shape (1, 3, 540, 960)
#
# 449: 540x960 5.1ms
# Speed: 164.7ms track, 5.1ms solution per image at shape (1, 3, 540, 960)
#
# 450: 540x960 3.8ms
# Speed: 168.5ms track, 3.8ms solution per image at shape (1, 3, 540, 960)
#
# 451: 540x960 3.2ms
# Speed: 174.2ms track, 3.2ms solution per image at shape (1, 3, 540, 960)
#
# 452: 540x960 3.1ms
# Speed: 170.2ms track, 3.1ms solution per image at shape (1, 3, 540, 960)
#
# 453: 540x960 3.1ms
# Speed: 193.1ms track, 3.1ms solution per image at shape (1, 3, 540, 960)
#
# 454: 540x960 1.9ms
# Speed: 168.4ms track, 1.9ms solution per image at shape (1, 3, 540, 960)
#
# 455: 540x960 3.1ms
# Speed: 179.9ms track, 3.1ms solution per image at shape (1, 3, 540, 960)
#
# 456: 540x960 3.1ms
# Speed: 173.3ms track, 3.1ms solution per image at shape (1, 3, 540, 960)
#
# 457: 540x960 3.2ms
# Speed: 173.4ms track, 3.2ms solution per image at shape (1, 3, 540, 960)
#
# 458: 540x960 3.1ms
# Speed: 173.3ms track, 3.1ms solution per image at shape (1, 3, 540, 960)
#
# 459: 540x960 2.7ms
# Speed: 179.0ms track, 2.7ms solution per image at shape (1, 3, 540, 960)
#
# 460: 540x960 3.0ms
# Speed: 168.4ms track, 3.0ms solution per image at shape (1, 3, 540, 960)
#
# 461: 540x960 2.9ms
# Speed: 165.3ms track, 2.9ms solution per image at shape (1, 3, 540, 960)
#
# 462: 540x960 3.4ms
# Speed: 169.5ms track, 3.4ms solution per image at shape (1, 3, 540, 960)
#
# 463: 540x960 2.7ms
# Speed: 168.6ms track, 2.7ms solution per image at shape (1, 3, 540, 960)
#
# 464: 540x960 5.0ms
# Speed: 195.5ms track, 5.0ms solution per image at shape (1, 3, 540, 960)
#
# 465: 540x960 3.5ms
# Speed: 171.7ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 466: 540x960 3.2ms
# Speed: 174.4ms track, 3.2ms solution per image at shape (1, 3, 540, 960)
#
# 467: 540x960 3.3ms
# Speed: 173.6ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 468: 540x960 4.1ms
# Speed: 176.1ms track, 4.1ms solution per image at shape (1, 3, 540, 960)
#
# 469: 540x960 3.6ms
# Speed: 169.5ms track, 3.6ms solution per image at shape (1, 3, 540, 960)
#
# 470: 540x960 3.3ms
# Speed: 183.2ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 471: 540x960 3.7ms
# Speed: 165.7ms track, 3.7ms solution per image at shape (1, 3, 540, 960)
#
# 472: 540x960 2.9ms
# Speed: 166.1ms track, 2.9ms solution per image at shape (1, 3, 540, 960)
#
# 473: 540x960 3.3ms
# Speed: 166.3ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 474: 540x960 2.8ms
# Speed: 163.1ms track, 2.8ms solution per image at shape (1, 3, 540, 960)
#
# 475: 540x960 3.8ms
# Speed: 166.1ms track, 3.8ms solution per image at shape (1, 3, 540, 960)
#
# 476: 540x960 2.9ms
# Speed: 176.6ms track, 2.9ms solution per image at shape (1, 3, 540, 960)
#
# 477: 540x960 3.0ms
# Speed: 172.1ms track, 3.0ms solution per image at shape (1, 3, 540, 960)
#
# 478: 540x960 2.4ms
# Speed: 172.8ms track, 2.4ms solution per image at shape (1, 3, 540, 960)
#
# 479: 540x960 2.6ms
# Speed: 168.5ms track, 2.6ms solution per image at shape (1, 3, 540, 960)
#
# 480: 540x960 3.2ms
# Speed: 171.4ms track, 3.2ms solution per image at shape (1, 3, 540, 960)
#
# 481: 540x960 2.8ms
# Speed: 179.7ms track, 2.8ms solution per image at shape (1, 3, 540, 960)
#
# 482: 540x960 2.7ms
# Speed: 173.9ms track, 2.7ms solution per image at shape (1, 3, 540, 960)
#
# 483: 540x960 3.7ms
# Speed: 166.1ms track, 3.7ms solution per image at shape (1, 3, 540, 960)
#
# 484: 540x960 3.3ms
# Speed: 169.5ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 485: 540x960 3.5ms
# Speed: 163.5ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 486: 540x960 3.1ms
# Speed: 169.7ms track, 3.1ms solution per image at shape (1, 3, 540, 960)
#
# 487: 540x960 2.9ms
# Speed: 182.1ms track, 2.9ms solution per image at shape (1, 3, 540, 960)
#
# 488: 540x960 3.5ms
# Speed: 169.7ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 489: 540x960 3.4ms
# Speed: 167.5ms track, 3.4ms solution per image at shape (1, 3, 540, 960)
#
# 490: 540x960 2.7ms
# Speed: 169.5ms track, 2.7ms solution per image at shape (1, 3, 540, 960)
#
# 491: 540x960 3.7ms
# Speed: 174.8ms track, 3.7ms solution per image at shape (1, 3, 540, 960)
#
# 492: 540x960 3.8ms
# Speed: 198.1ms track, 3.8ms solution per image at shape (1, 3, 540, 960)
#
# 493: 540x960 2.5ms
# Speed: 178.1ms track, 2.5ms solution per image at shape (1, 3, 540, 960)
#
# 494: 540x960 2.0ms
# Speed: 176.4ms track, 2.0ms solution per image at shape (1, 3, 540, 960)
#
# 495: 540x960 2.2ms
# Speed: 173.1ms track, 2.2ms solution per image at shape (1, 3, 540, 960)
#
# 496: 540x960 2.2ms
# Speed: 176.1ms track, 2.2ms solution per image at shape (1, 3, 540, 960)
#
# 497: 540x960 2.8ms
# Speed: 174.8ms track, 2.8ms solution per image at shape (1, 3, 540, 960)
#
# 498: 540x960 2.4ms
# Speed: 188.7ms track, 2.4ms solution per image at shape (1, 3, 540, 960)
#
# 499: 540x960 2.4ms
# Speed: 179.0ms track, 2.4ms solution per image at shape (1, 3, 540, 960)
#
# 500: 540x960 2.7ms
# Speed: 175.6ms track, 2.7ms solution per image at shape (1, 3, 540, 960)
#
# 501: 540x960 2.4ms
# Speed: 170.2ms track, 2.4ms solution per image at shape (1, 3, 540, 960)
#
# 502: 540x960 3.8ms
# Speed: 275.0ms track, 3.8ms solution per image at shape (1, 3, 540, 960)
#
# 503: 540x960 5.1ms
# Speed: 286.4ms track, 5.1ms solution per image at shape (1, 3, 540, 960)
#
# 504: 540x960 3.4ms
# Speed: 269.6ms track, 3.4ms solution per image at shape (1, 3, 540, 960)
#
# 505: 540x960 4.9ms
# Speed: 258.6ms track, 4.9ms solution per image at shape (1, 3, 540, 960)
#
# 506: 540x960 4.6ms
# Speed: 265.7ms track, 4.6ms solution per image at shape (1, 3, 540, 960)
#
# 507: 540x960 4.6ms
# Speed: 283.0ms track, 4.6ms solution per image at shape (1, 3, 540, 960)
#
# 508: 540x960 4.5ms
# Speed: 262.5ms track, 4.5ms solution per image at shape (1, 3, 540, 960)
#
# 509: 540x960 5.8ms
# ...
#
# 516: 540x960 3.4ms
# Speed: 186.2ms track, 3.4ms solution per image at shape (1, 3, 540, 960)
#
# 517: 540x960 3.3ms
# Speed: 171.3ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 518: 540x960 3.4ms
# Speed: 169.0ms track, 3.4ms solution per image at shape (1, 3, 540, 960)
#
# 519: 540x960 3.1ms
# Speed: 178.1ms track, 3.1ms solution per image at shape (1, 3, 540, 960)
#
# 520: 540x960 4.9ms
# Speed: 188.1ms track, 4.9ms solution per image at shape (1, 3, 540, 960)
#
# 521: 540x960 3.3ms
# Speed: 185.2ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 522: 540x960 3.6ms
# Speed: 165.0ms track, 3.6ms solution per image at shape (1, 3, 540, 960)
#
# 523: 540x960 4.8ms
# Speed: 176.3ms track, 4.8ms solution per image at shape (1, 3, 540, 960)
#
# 524: 540x960 3.0ms
# Speed: 166.3ms track, 3.0ms solution per image at shape (1, 3, 540, 960)
#
# 525: 540x960 3.0ms
# Speed: 170.3ms track, 3.0ms solution per image at shape (1, 3, 540, 960)
#
# 526: 540x960 2.9ms
# Speed: 169.2ms track, 2.9ms solution per image at shape (1, 3, 540, 960)
#
# 527: 540x960 3.4ms
# Speed: 180.0ms track, 3.4ms solution per image at shape (1, 3, 540, 960)
#
# 528: 540x960 3.3ms
# Speed: 172.4ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 529: 540x960 3.3ms
# Speed: 170.4ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 530: 540x960 4.5ms
# Speed: 166.2ms track, 4.5ms solution per image at shape (1, 3, 540, 960)
#
# 531: 540x960 4.4ms
# Speed: 172.1ms track, 4.4ms solution per image at shape (1, 3, 540, 960)
#
# 532: 540x960 4.4ms
# Speed: 180.6ms track, 4.4ms solution per image at shape (1, 3, 540, 960)
#
# 533: 540x960 4.1ms
# Speed: 164.3ms track, 4.1ms solution per image at shape (1, 3, 540, 960)
#
# 534: 540x960 4.0ms
# Speed: 168.5ms track, 4.0ms solution per image at shape (1, 3, 540, 960)
#
# 535: 540x960 3.4ms
# Speed: 174.0ms track, 3.4ms solution per image at shape (1, 3, 540, 960)
#
# 536: 540x960 3.0ms
# Speed: 171.2ms track, 3.0ms solution per image at shape (1, 3, 540, 960)
#
# 537: 540x960 3.2ms
# Speed: 167.6ms track, 3.2ms solution per image at shape (1, 3, 540, 960)
#
# 538: 540x960 3.9ms
# Speed: 185.6ms track, 3.9ms solution per image at shape (1, 3, 540, 960)
#
# 539: 540x960 2.7ms
# Speed: 163.8ms track, 2.7ms solution per image at shape (1, 3, 540, 960)
#
# 540: 540x960 3.4ms
# Speed: 169.4ms track, 3.4ms solution per image at shape (1, 3, 540, 960)
#
# 541: 540x960 2.8ms
# Speed: 178.8ms track, 2.8ms solution per image at shape (1, 3, 540, 960)
#
# 542: 540x960 2.7ms
# Speed: 175.1ms track, 2.7ms solution per image at shape (1, 3, 540, 960)
#
# 543: 540x960 3.7ms
# Speed: 193.1ms track, 3.7ms solution per image at shape (1, 3, 540, 960)
#
# 544: 540x960 4.1ms
# Speed: 179.7ms track, 4.1ms solution per image at shape (1, 3, 540, 960)
#
# 545: 540x960 2.8ms
# Speed: 174.2ms track, 2.8ms solution per image at shape (1, 3, 540, 960)
#
# 546: 540x960 2.6ms
# Speed: 168.1ms track, 2.6ms solution per image at shape (1, 3, 540, 960)
#
# 547: 540x960 3.1ms
# Speed: 174.5ms track, 3.1ms solution per image at shape (1, 3, 540, 960)
#
# 548: 540x960 2.5ms
# Speed: 173.8ms track, 2.5ms solution per image at shape (1, 3, 540, 960)
#
# 549: 540x960 2.7ms
# Speed: 180.9ms track, 2.7ms solution per image at shape (1, 3, 540, 960)
#
# 550: 540x960 2.6ms
# Speed: 170.1ms track, 2.6ms solution per image at shape (1, 3, 540, 960)
#
# 551: 540x960 2.4ms
# Speed: 173.5ms track, 2.4ms solution per image at shape (1, 3, 540, 960)
#
# 552: 540x960 3.2ms
# Speed: 170.2ms track, 3.2ms solution per image at shape (1, 3, 540, 960)
#
# 553: 540x960 3.0ms
# Speed: 171.0ms track, 3.0ms solution per image at shape (1, 3, 540, 960)
#
# 554: 540x960 4.7ms
# Speed: 187.2ms track, 4.7ms solution per image at shape (1, 3, 540, 960)
#
# 555: 540x960 2.3ms
# Speed: 171.0ms track, 2.3ms solution per image at shape (1, 3, 540, 960)
#
# 556: 540x960 3.9ms
# Speed: 170.4ms track, 3.9ms solution per image at shape (1, 3, 540, 960)
#
# 557: 540x960 3.3ms
# Speed: 171.0ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 558: 540x960 2.5ms
# Speed: 173.1ms track, 2.5ms solution per image at shape (1, 3, 540, 960)
#
# 559: 540x960 2.9ms
# Speed: 167.2ms track, 2.9ms solution per image at shape (1, 3, 540, 960)
#
# 560: 540x960 2.4ms
# Speed: 184.2ms track, 2.4ms solution per image at shape (1, 3, 540, 960)
#
# 561: 540x960 3.1ms
# Speed: 170.4ms track, 3.1ms solution per image at shape (1, 3, 540, 960)
#
# 562: 540x960 2.8ms
# Speed: 168.4ms track, 2.8ms solution per image at shape (1, 3, 540, 960)
#
# 563: 540x960 3.0ms
# Speed: 167.7ms track, 3.0ms solution per image at shape (1, 3, 540, 960)
#
# 564: 540x960 3.4ms
# Speed: 167.3ms track, 3.4ms solution per image at shape (1, 3, 540, 960)
#
# 565: 540x960 5.5ms
# Speed: 284.2ms track, 5.5ms solution per image at shape (1, 3, 540, 960)
#
# 566: 540x960 4.4ms
# Speed: 257.6ms track, 4.4ms solution per image at shape (1, 3, 540, 960)
#
# 567: 540x960 4.3ms
# Speed: 264.8ms track, 4.3ms solution per image at shape (1, 3, 540, 960)
#
# 568: 540x960 3.8ms
# Speed: 258.4ms track, 3.8ms solution per image at shape (1, 3, 540, 960)
#
# 569: 540x960 3.5ms
# Speed: 274.9ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 570: 540x960 4.1ms
# Speed: 254.3ms track, 4.1ms solution per image at shape (1, 3, 540, 960)
#
# 571: 540x960 4.9ms
# Speed: 271.8ms track, 4.9ms solution per image at shape (1, 3, 540, 960)
#
# 572: 540x960 5.0ms
# Speed: 256.1ms track, 5.0ms solution per image at shape (1, 3, 540, 960)
#
# 573: 540x960 6.5ms
# Speed: 290.4ms track, 6.5ms solution per image at shape (1, 3, 540, 960)
#
# 574: 540x960 3.8ms
# Speed: 236.2ms track, 3.8ms solution per image at shape (1, 3, 540, 960)
#
# 575: 540x960 3.4ms
# Speed: 171.1ms track, 3.4ms solution per image at shape (1, 3, 540, 960)
#
# 576: 540x960 2.4ms
# Speed: 173.9ms track, 2.4ms solution per image at shape (1, 3, 540, 960)
#
# 577: 540x960 3.5ms
# Speed: 180.5ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 578: 540x960 2.3ms
# Speed: 189.3ms track, 2.3ms solution per image at shape (1, 3, 540, 960)
#
# 579: 540x960 2.7ms
# Speed: 177.4ms track, 2.7ms solution per image at shape (1, 3, 540, 960)
#
# 580: 540x960 2.5ms
# Speed: 175.8ms track, 2.5ms solution per image at shape (1, 3, 540, 960)
#
# 581: 540x960 2.3ms
# Speed: 172.8ms track, 2.3ms solution per image at shape (1, 3, 540, 960)
#
# 582: 540x960 2.2ms
# Speed: 171.8ms track, 2.2ms solution per image at shape (1, 3, 540, 960)
#
# 583: 540x960 3.8ms
# Speed: 174.2ms track, 3.8ms solution per image at shape (1, 3, 540, 960)
#
# 584: 540x960 3.3ms
# Speed: 181.8ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 585: 540x960 2.6ms
# Speed: 171.9ms track, 2.6ms solution per image at shape (1, 3, 540, 960)
#
# 586: 540x960 2.4ms
# Speed: 168.6ms track, 2.4ms solution per image at shape (1, 3, 540, 960)
#
# 587: 540x960 3.3ms
# Speed: 171.4ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 588: 540x960 3.5ms
# Speed: 198.8ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 589: 540x960 3.6ms
# Speed: 204.3ms track, 3.6ms solution per image at shape (1, 3, 540, 960)
#
# 590: 540x960 3.6ms
# Speed: 176.5ms track, 3.6ms solution per image at shape (1, 3, 540, 960)
#
# 591: 540x960 3.8ms
# Speed: 164.5ms track, 3.8ms solution per image at shape (1, 3, 540, 960)
#
# 592: 540x960 3.3ms
# Speed: 174.4ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 593: 540x960 3.6ms
# Speed: 168.8ms track, 3.6ms solution per image at shape (1, 3, 540, 960)
#
# 594: 540x960 4.0ms
# Speed: 188.6ms track, 4.0ms solution per image at shape (1, 3, 540, 960)
#
# 595: 540x960 3.5ms
# Speed: 173.2ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 596: 540x960 4.2ms
# Speed: 167.6ms track, 4.2ms solution per image at shape (1, 3, 540, 960)
#
# 597: 540x960 4.1ms
# Speed: 167.3ms track, 4.1ms solution per image at shape (1, 3, 540, 960)
#
# 598: 540x960 3.1ms
# Speed: 182.9ms track, 3.1ms solution per image at shape (1, 3, 540, 960)
#
# 599: 540x960 3.2ms
# Speed: 168.3ms track, 3.2ms solution per image at shape (1, 3, 540, 960)
#
# 600: 540x960 3.9ms
# Speed: 179.1ms track, 3.9ms solution per image at shape (1, 3, 540, 960)
#
# 601: 540x960 2.9ms
# Speed: 176.6ms track, 2.9ms solution per image at shape (1, 3, 540, 960)
#
# 602: 540x960 3.7ms
# Speed: 170.7ms track, 3.7ms solution per image at shape (1, 3, 540, 960)
#
# 603: 540x960 4.8ms
# Speed: 179.5ms track, 4.8ms solution per image at shape (1, 3, 540, 960)
#
# 604: 540x960 3.5ms
# Speed: 175.6ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 605: 540x960 4.4ms
# Speed: 186.7ms track, 4.4ms solution per image at shape (1, 3, 540, 960)
#
# 606: 540x960 4.2ms
# Speed: 178.9ms track, 4.2ms solution per image at shape (1, 3, 540, 960)
#
# 607: 540x960 3.2ms
# Speed: 173.1ms track, 3.2ms solution per image at shape (1, 3, 540, 960)
#
# 608: 540x960 3.1ms
# Speed: 170.3ms track, 3.1ms solution per image at shape (1, 3, 540, 960)
#
# 609: 540x960 3.3ms
# Speed: 167.9ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 610: 540x960 3.0ms
# Speed: 173.1ms track, 3.0ms solution per image at shape (1, 3, 540, 960)
#
# 611: 540x960 3.0ms
# Speed: 187.1ms track, 3.0ms solution per image at shape (1, 3, 540, 960)
#
# 612: 540x960 3.0ms
# Speed: 177.0ms track, 3.0ms solution per image at shape (1, 3, 540, 960)
#
# 613: 540x960 2.7ms
# Speed: 167.9ms track, 2.7ms solution per image at shape (1, 3, 540, 960)
#
# 614: 540x960 3.5ms
# Speed: 188.7ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 615: 540x960 4.2ms
# Speed: 171.8ms track, 4.2ms solution per image at shape (1, 3, 540, 960)
#
# 616: 540x960 4.1ms
# Speed: 191.1ms track, 4.1ms solution per image at shape (1, 3, 540, 960)
#
# 617: 540x960 3.4ms
# Speed: 174.5ms track, 3.4ms solution per image at shape (1, 3, 540, 960)
#
# 618: 540x960 3.5ms
# Speed: 180.3ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 619: 540x960 3.2ms
# Speed: 172.1ms track, 3.2ms solution per image at shape (1, 3, 540, 960)
#
# 620: 540x960 3.7ms
# Speed: 175.2ms track, 3.7ms solution per image at shape (1, 3, 540, 960)
#
# 621: 540x960 3.7ms
# Speed: 169.7ms track, 3.7ms solution per image at shape (1, 3, 540, 960)
#
# 622: 540x960 3.3ms
# Speed: 191.6ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 623: 540x960 3.3ms
# Speed: 166.7ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 624: 540x960 3.2ms
# Speed: 170.5ms track, 3.2ms solution per image at shape (1, 3, 540, 960)
#
# 625: 540x960 3.4ms
# Speed: 171.9ms track, 3.4ms solution per image at shape (1, 3, 540, 960)
#
# 626: 540x960 3.5ms
# Speed: 174.7ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 627: 540x960 5.9ms
# Speed: 244.7ms track, 5.9ms solution per image at shape (1, 3, 540, 960)
#
# 628: 540x960 5.1ms
# Speed: 270.2ms track, 5.1ms solution per image at shape (1, 3, 540, 960)
#
# 629: 540x960 5.5ms
# Speed: 274.2ms track, 5.5ms solution per image at shape (1, 3, 540, 960)
#
# 630: 540x960 5.4ms
# Speed: 287.6ms track, 5.4ms solution per image at shape (1, 3, 540, 960)
#
# 631: 540x960 5.2ms
# Speed: 266.2ms track, 5.2ms solution per image at shape (1, 3, 540, 960)
#
# 632: 540x960 5.2ms
# Speed: 252.0ms track, 5.2ms solution per image at shape (1, 3, 540, 960)
#
# 633: 540x960 5.2ms
# Speed: 269.4ms track, 5.2ms solution per image at shape (1, 3, 540, 960)
#
# 634: 540x960 5.6ms
# Speed: 268.6ms track, 5.6ms solution per image at shape (1, 3, 540, 960)
#
# 635: 540x960 5.2ms
# Speed: 281.8ms track, 5.2ms solution per image at shape (1, 3, 540, 960)
#
# 636: 540x960 3.9ms
# Speed: 285.4ms track, 3.9ms solution per image at shape (1, 3, 540, 960)
#
# 637: 540x960 3.8ms
# Speed: 174.4ms track, 3.8ms solution per image at shape (1, 3, 540, 960)
#
# 638: 540x960 3.4ms
# Speed: 180.5ms track, 3.4ms solution per image at shape (1, 3, 540, 960)
#
# 639: 540x960 2.9ms
# Speed: 196.0ms track, 2.9ms solution per image at shape (1, 3, 540, 960)
#
# 640: 540x960 3.0ms
# Speed: 172.6ms track, 3.0ms solution per image at shape (1, 3, 540, 960)
#
# 641: 540x960 3.2ms
# Speed: 171.8ms track, 3.2ms solution per image at shape (1, 3, 540, 960)
#
# 642: 540x960 3.0ms
# Speed: 164.4ms track, 3.0ms solution per image at shape (1, 3, 540, 960)
#
# 643: 540x960 3.1ms
# Speed: 171.0ms track, 3.1ms solution per image at shape (1, 3, 540, 960)
#
# 644: 540x960 3.4ms
# Speed: 185.3ms track, 3.4ms solution per image at shape (1, 3, 540, 960)
#
# 645: 540x960 3.5ms
# Speed: 167.5ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 646: 540x960 4.3ms
# Speed: 170.2ms track, 4.3ms solution per image at shape (1, 3, 540, 960)
#
# 647: 540x960 3.7ms
# Speed: 168.2ms track, 3.7ms solution per image at shape (1, 3, 540, 960)
#
# 648: 540x960 3.5ms
# Speed: 165.0ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 649: 540x960 3.4ms
# Speed: 172.7ms track, 3.4ms solution per image at shape (1, 3, 540, 960)
#
# 650: 540x960 3.5ms
# Speed: 185.4ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 651: 540x960 3.3ms
# Speed: 168.4ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 652: 540x960 3.7ms
# Speed: 174.0ms track, 3.7ms solution per image at shape (1, 3, 540, 960)
#
# 653: 540x960 3.7ms
# Speed: 172.1ms track, 3.7ms solution per image at shape (1, 3, 540, 960)
#
# 654: 540x960 4.5ms
# Speed: 174.4ms track, 4.5ms solution per image at shape (1, 3, 540, 960)
#
# 655: 540x960 7.1ms
# Speed: 173.5ms track, 7.1ms solution per image at shape (1, 3, 540, 960)
#
# 656: 540x960 4.4ms
# Speed: 178.5ms track, 4.4ms solution per image at shape (1, 3, 540, 960)
#
# 657: 540x960 4.4ms
# Speed: 174.4ms track, 4.4ms solution per image at shape (1, 3, 540, 960)
#
# 658: 540x960 4.9ms
# Speed: 171.2ms track, 4.9ms solution per image at shape (1, 3, 540, 960)
#
# 659: 540x960 4.4ms
# Speed: 174.5ms track, 4.4ms solution per image at shape (1, 3, 540, 960)
#
# 660: 540x960 3.8ms
# Speed: 167.5ms track, 3.8ms solution per image at shape (1, 3, 540, 960)
#
# 661: 540x960 4.3ms
# Speed: 185.1ms track, 4.3ms solution per image at shape (1, 3, 540, 960)
#
# 662: 540x960 3.9ms
# Speed: 167.6ms track, 3.9ms solution per image at shape (1, 3, 540, 960)
#
# 663: 540x960 4.1ms
# Speed: 174.1ms track, 4.1ms solution per image at shape (1, 3, 540, 960)
#
# 664: 540x960 3.5ms
# Speed: 175.7ms track, 3.5ms solution per image at shape (1, 3, 540, 960)
#
# 665: 540x960 3.2ms
# Speed: 168.2ms track, 3.2ms solution per image at shape (1, 3, 540, 960)
#
# 666: 540x960 3.3ms
# Speed: 167.6ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 667: 540x960 3.0ms
# Speed: 182.5ms track, 3.0ms solution per image at shape (1, 3, 540, 960)
#
# 668: 540x960 2.9ms
# Speed: 172.2ms track, 2.9ms solution per image at shape (1, 3, 540, 960)
#
# 669: 540x960 4.5ms
# Speed: 169.5ms track, 4.5ms solution per image at shape (1, 3, 540, 960)
#
# 670: 540x960 4.4ms
# Speed: 193.0ms track, 4.4ms solution per image at shape (1, 3, 540, 960)
#
# 671: 540x960 2.6ms
# Speed: 167.2ms track, 2.6ms solution per image at shape (1, 3, 540, 960)
#
# 672: 540x960 3.0ms
# Speed: 184.6ms track, 3.0ms solution per image at shape (1, 3, 540, 960)
#
# 673: 540x960 2.7ms
# Speed: 170.1ms track, 2.7ms solution per image at shape (1, 3, 540, 960)
#
# 674: 540x960 2.3ms
# Speed: 178.7ms track, 2.3ms solution per image at shape (1, 3, 540, 960)
#
# 675: 540x960 2.2ms
# Speed: 173.9ms track, 2.2ms solution per image at shape (1, 3, 540, 960)
#
# 676: 540x960 4.4ms
# Speed: 167.3ms track, 4.4ms solution per image at shape (1, 3, 540, 960)
#
# 677: 540x960 4.1ms
# Speed: 168.5ms track, 4.1ms solution per image at shape (1, 3, 540, 960)
#
# 678: 540x960 3.8ms
# Speed: 180.9ms track, 3.8ms solution per image at shape (1, 3, 540, 960)
#
# 679: 540x960 2.7ms
# Speed: 170.5ms track, 2.7ms solution per image at shape (1, 3, 540, 960)
#
# 680: 540x960 2.6ms
# Speed: 173.8ms track, 2.6ms solution per image at shape (1, 3, 540, 960)
#
# 681: 540x960 3.1ms
# Speed: 186.9ms track, 3.1ms solution per image at shape (1, 3, 540, 960)
#
# 682: 540x960 3.9ms
# Speed: 174.9ms track, 3.9ms solution per image at shape (1, 3, 540, 960)
#
# 683: 540x960 3.0ms
# Speed: 186.0ms track, 3.0ms solution per image at shape (1, 3, 540, 960)
#
# 684: 540x960 3.3ms
# Speed: 164.7ms track, 3.3ms solution per image at shape (1, 3, 540, 960)
#
# 685: 540x960 3.0ms
# Speed: 162.0ms track, 3.0ms solution per image at shape (1, 3, 540, 960)
#
# 686: 540x960 3.6ms
# Speed: 166.1ms track, 3.6ms solution per image at shape (1, 3, 540, 960)
#
# Video frame is empty or processing is complete.
